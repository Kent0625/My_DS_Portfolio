# %% [markdown]
# # Activity 1: Perceptron
#
# Demonstration of a single artificial neuron.

# %%
import numpy as np

x = np.array([0.5, -0.2])
w = np.array([0.4, 0.3])
b = 0.1
z = np.dot(x, w) + b
print("Neuron output:", z)
